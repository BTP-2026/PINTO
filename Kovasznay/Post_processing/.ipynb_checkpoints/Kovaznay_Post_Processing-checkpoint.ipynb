# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import matplotlib as mpl
from scipy.io import loadmat

get_dir = os.getcwd()
os.chdir(get_dir)

np.random.seed(1234)
# Out:
# 2025-04-13 15:15:17.772246: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-13 15:15:17.772275: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-13 15:15:17.773387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-13 15:15:17.779014: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-13 15:15:18.389869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def get_fvalues(x, y, nue):
    
    zeta = (0.5 / nue) - np.sqrt((1 / (4 * nue ** 2)) + 4 * np.pi ** 2)

    u_val = 1 - np.exp(zeta * x) * np.cos(2 * np.pi * y)
    v_val = (zeta / (2 * np.pi)) * np.exp(zeta * x) * np.sin(2 * np.pi * y)
    p_val = 0.5 * (1 - np.exp(2 * zeta * x))

    return u_val, v_val, p_val

def get_predictions(model, test_data):
    
    u_test, v_test, p_test = model.predict(test_data, batch_size=4096)
    return u_test, v_test, p_test
def get_repeated_tensors(x, y, u, v, p, num_samples):
    return (np.repeat(x.reshape((1, -1)), num_samples, axis=0), 
           np.repeat(y.reshape((1, -1)), num_samples, axis=0),
           np.repeat(u.reshape((1, -1)), num_samples, axis=0),
           np.repeat(v.reshape((1, -1)), num_samples, axis=0),
           np.repeat(p.reshape((1, -1)), num_samples, axis=0))

# %%
def get_true_test_values(model, nue, xlim, ylim, grid_size, seq_dir, TP=True):
    
    true_val = []
    pred_val = []
    u_val = {'true': [], 'pred': []}
    v_val = {'true': [], 'pred': []}
    
    xdisc = np.linspace(start=xlim[0], stop=xlim[1], num=grid_size)
    ydisc = np.linspace(start=ylim[0], stop=ylim[1], num=grid_size)
    
    X, Y = np.meshgrid(xdisc, ydisc)
    grid_loc = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
    coord_val = pd.read_csv(seq_dir)
    x_seq, y_seq = coord_val['0'].values, coord_val['1'].values
    
    for i in nue:
        u_seq, v_seq, p_seq = get_fvalues(x_seq, y_seq, nue=i)
        xbc, ybc, ubc, vbc, pbc = get_repeated_tensors(x_seq, y_seq, u_seq, v_seq, p_seq, num_samples=len(grid_loc))
        if TP:
            test_data = [grid_loc[:, 0:1], grid_loc[:, 1:], xbc, ybc, ubc, vbc, pbc]
        else:
            test_data = [grid_loc[:, 0:1], grid_loc[:, 1:], ubc, vbc, pbc]
        
        u_test, v_test, p_test = get_predictions(model, test_data)
        
        u_test = u_test.reshape(X.shape)
        v_test = v_test.reshape(X.shape)
    
        u_true, v_true, p_true = get_fvalues(x=grid_loc[:, 0:1], y=grid_loc[:, 1:], nue=i)
        
        u_true = u_true.reshape(X.shape)
        v_true = v_true.reshape(X.shape)
        
        true_mag = (u_true ** 2 + v_true ** 2)**0.5
        pred_mag = (u_test ** 2 + v_test ** 2)**0.5
        
        true_val.append(true_mag)
        pred_val.append(pred_mag)
        
        u_val['true'].append(u_true)
        u_val['pred'].append(u_test)
        v_val['true'].append(v_true)
        v_val['pred'].append(v_test)
        
    return X, Y, true_val, pred_val, u_val, v_val

# %%
def get_plots(x, y, true_val, pred_val, u_val, v_val, grid_spec, plot_title, plot_save, 
              plot_dir, fig_size,shrink=1, dm=False, lxd = [0.5, 0.5],lyd=[0.1, 0.9], 
              lx=0.25, rx=0.75, text_y=0.9, clim=[0., 4.5], eclim = [0., 0.035], 
              lbs=['PINTO Prediction \n Y', 'Analytical Solution \n Y', 'Relative Error \n Y'], 
              dt=['Seen', 'Unseen'], cbar_kwargs=None, value=None):
    
    fig, ax = plt.subplots(3, len(true_val),figsize=fig_size, sharex='col', sharey='row', 
                           gridspec_kw =grid_spec)
    
    # Create two GridSpec objects for left and right sections
    gs = mpl.gridspec.GridSpec(4, 4, figure=fig)
    
    def fmt(x, pos):
        return f'{x:.1e}'
    level = np.linspace(clim[0], clim[1], num=10)
    err_level = np.linspace(eclim[0], eclim[1], num=10)
    
    for j in range(len(true_val)):
     
        pres = ax[0][j].streamplot(x, y, u_val['pred'][j], v_val['pred'][j], color='k', 
                                    linewidth=0.5)
        pre = ax[0][j].contourf(x, y, pred_val[j], level, cmap='rainbow')

        trus = ax[1][j].streamplot(x, y, u_val['true'][j], v_val['true'][j], color='k', 
                                    linewidth=0.5)
        ref = ax[1][j].contourf(x, y, true_val[j], level, cmap='rainbow')
        
        rel_err = np.log10(abs(true_val[j] - pred_val[j])/(1 + abs(true_val[j])))
        
        if dm:
            er = ax[2][j].contourf(x, y, rel_err, err_level, cmap='Blues', extend='both')
            er.cmap.set_under('orange')
            er.cmap.set_over('orange')
        else:
            er=ax[2][j].contourf(x, y, rel_err, err_level, cmap='Blues')
        
        ax[0][j].set_title(plot_title[0][j],fontsize=10, fontweight='bold')
        ax[0][j].set_xlim(xlim[0], xlim[1])
        ax[0][j].set_ylim(ylim[0], ylim[1])

        ax[1][j].set_xlim(xlim[0], xlim[1])
        ax[1][j].set_ylim(ylim[0], ylim[1])
        
        ax[2][j].set_xlabel('X', fontsize=10, fontweight='bold')

        for row in ax:
            row[j].set_aspect(value, adjustable='box')

    pcbar = fig.colorbar(pre, ax=ax[0, :], **cbar_kwargs)
    pcbar.ax.yaxis.set_major_formatter(tick.FormatStrFormatter('%.2f'))
    pcbar.set_label('|V| (non-dim)', fontsize=10, fontweight='bold')
    
    tcbar = fig.colorbar(ref, ax=ax[1, :], **cbar_kwargs)
    tcbar.ax.yaxis.set_major_formatter(tick.FormatStrFormatter('%.2f'))
    tcbar.set_label('|V| (non-dim)', fontsize=10, fontweight='bold')
    
    ecbar = fig.colorbar(er, ax = ax[2, :], **cbar_kwargs)
    ecbar.set_label('Log$_{10}$(Relative Error)', fontsize=10, fontweight='bold')
    # ecbar.formatter = tick.FuncFormatter(fmt)
    # ecbar.update_ticks()
    
    ax[0][0].set_ylabel(lbs[0], fontsize=10, fontweight='bold')
    ax[1][0].set_ylabel(lbs[1], fontsize=10, fontweight='bold')
    ax[2][0].set_ylabel(lbs[2], fontsize=10, fontweight='bold')

    fig.text(lx, text_y, dt[0], ha='center', va='center', fontsize=12, fontweight='bold')
    fig.text(rx, text_y, dt[1], ha='center', va='center', fontsize=12, fontweight='bold')

    # Add vertical line using figure coordinates
    line = plt.Line2D(lxd, lyd, transform=fig.transFigure, color='black', linewidth=2)
    fig.add_artist(line)
    
    if plot_save:
        plt.savefig(plot_dir + '.png', dpi=300, bbox_inches = 'tight', format='png')

# %% [markdown]
# ## Figure_7: kovasznay Flow

# %%
PINTO_model = keras.models.load_model('../Trained_models/KF_PINTO/KF_PINTO_model/')

train_test_nue = [1/20, 1/50, 1/15, 1/25]
xlim = [-0.5, 1.0]
ylim = [-0.5, 1.5]
grid_size = 64
seq_dir = '../Trained_models/KF_PINTO/seq_data.csv'

x, y, tno_true, tno_pred, tno_u_val, tno_v_val = get_true_test_values(
    model=PINTO_model, nue=train_test_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size, seq_dir=seq_dir)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
pdir = 'Figure_7'
pt = [['Re=20', 'Re=50', 'Re=15', 'Re=25']] # titles for each column
plt_save = False # saving the plot 
eclim = [-4, 0]  # error countour colorbar limits
clim = [0., 4.5] # prediction and true contour plots colorbar limits
cbar_kwargs = {
        'fraction': 0.0112, 
        'pad': 0.01,
        'format': tick.FormatStrFormatter('%.2f')
    }

grid_spec = {'wspace': 0.12, 'hspace': -0.1, 'width_ratios':[1, 1, 1, 1], 'height_ratios':[1, 1, 1]}
get_plots(x,  y, true_val=tno_true, pred_val=tno_pred, u_val=tno_u_val, v_val=tno_v_val, 
          plot_save=plt_save, grid_spec=grid_spec, plot_title=pt, plot_dir=pdir, fig_size=(12,9), shrink=1,
          lxd=[0.505, 0.505], lyd=[0.1, 0.92], lx=0.315, rx=0.715, text_y=0.9, clim=clim, eclim=eclim,
          lbs=['PINTO Prediction \n Y', 'Analytical Solution \n Y', 'Relative Error \n Y'], 
	  dt=['Seen Re', 'Unseen Re'], cbar_kwargs=cbar_kwargs, value=1.5/2.)

# %% [markdown]
# ## PI-DeepONet Plots

# %%
pid_model = keras.models.load_model('../Trained_models/KF_DeepONet/KF_Deeponet_model.keras')

seq_dir = '../Trained_models/KF_DeepONet/seq_data.csv'


x, y, pid_true, pid_pred, pid_u_val, pid_v_val = get_true_test_values(
    model=pid_model, nue=train_test_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size, seq_dir=seq_dir, TP=False)
# Out:
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
pdir = 'PI_DeepONets_Kovasznay_training_testing_plots'
pt = [['Re=20', 'Re=50', 'Re=15', 'Re=25']] # plot titles for each column
plt_save = False # saving the plot
eclim = [-4, 0]  # error countour colorbar limits
clim = [0., 4.5] # prediction and true contour plots colorbar limits
cbar_kwargs = {
        'fraction': 0.0112, 
        'pad': 0.01,
        'format': tick.FormatStrFormatter('%.2f')
    }

grid_spec = {'wspace': 0.11, 'hspace': 0.1, 'width_ratios':[1, 1, 1, 1], 'height_ratios':[1, 1, 1]}
get_plots(x,  y, true_val=pid_true, pred_val=pid_pred, u_val=pid_u_val, v_val=pid_v_val, 
          plot_save=plt_save, grid_spec=grid_spec, plot_title=pt, plot_dir=pdir, fig_size=(10,8), shrink=1, dm=True,
          lxd=[0.512, 0.512], lyd=[0.1, 0.92], lx=0.315, rx=0.715, text_y=0.92, clim=clim, eclim=eclim,
          lbs=['PINTO Prediction \n Y', 'Analytical Solution \n Y', 'Relative Error \n Y'], 
	  dt=['Seen Re', 'Unseen Re'], cbar_kwargs=cbar_kwargs, value=1.5/2.)

# %% [markdown]
# ## Table1: Performance metrics

# %%
training_nue = [1/20, 1/30, 1/50, 1/80]
testing_nue = 1/np.random.uniform(low=10., high=100., size=[1, 20]).reshape(-1)

# %%
def get_metrics(true_val, pred_val):
    rel_err = abs(np.concatenate(true_val, axis=0) - np.concatenate(pred_val, axis=0))/(1 + abs(np.concatenate(true_val)))
    mean_metric = np.mean(rel_err)
    std_metric = np.std(rel_err)
    
    return mean_metric, std_metric

# %%
sens_dir = '../Trained_models/KF_PINTO/seq_data.csv'

_, _, tno_train_true, tno_train_pred, tno_tr_u_val, tno_tr_v_val = get_true_test_values(
    model=PINTO_model, nue=training_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size, seq_dir=seq_dir)

_, _, tno_test_true, tno_test_pred, tno_ts_u_val, tno_ts_v_val = get_true_test_values(
    model=PINTO_model, nue=testing_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size,seq_dir=seq_dir)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
sens_dir = '../Trained_models/KF_DeepONet/seq_data.csv'

_, _, pid_train_true, pid_train_pred, pid_tr_u_val, pid_tr_v_val = get_true_test_values(
    model=pid_model, nue=training_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size, seq_dir=seq_dir, TP=False)

_, _, pid_test_true, pid_test_pred, pid_ts_u_val, pid_ts_v_val = get_true_test_values(
    model=pid_model, nue=testing_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size,seq_dir=seq_dir, TP=False)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
print("PINTO Metrics")

train_mean_metric, train_std_metric = get_metrics(tno_train_true, tno_train_pred)
test_mean_metric, test_std_metric = get_metrics(tno_test_true, tno_test_pred)

print("mean relative error across all training sets is: ",train_mean_metric)
print("std of relative error across training sets is: ",train_std_metric)
print("mean relative error across all testing sets is: ",test_mean_metric)
print("std of relative error across testing sets is: ",test_std_metric)
# Out:
# PINTO Metrics
# mean relative error across all training sets is:  0.0003769718476794449
# std of relative error across training sets is:  0.0003254653971056996
# mean relative error across all testing sets is:  0.0041030435248669474
# std of relative error across testing sets is:  0.025485504717452038

# %%
print("PI-DeepONets Metrics")

train_mean_metric, train_std_metric = get_metrics(pid_train_true, pid_train_pred)
test_mean_metric, test_std_metric = get_metrics(pid_test_true, pid_test_pred)

print("mean relative error across all training sets is: ",train_mean_metric)
print("std of relative error across training sets is: ",train_std_metric)
print("mean relative error across all testing sets is: ",test_mean_metric)
print("std of relative error across testing sets is: ",test_std_metric)
# Out:
# PI-DeepONets Metrics
# mean relative error across all training sets is:  0.0008049645468666074
# std of relative error across training sets is:  0.0006673126404173384
# mean relative error across all testing sets is:  0.022576300008607855
# std of relative error across testing sets is:  0.06547687961566731

# %% [markdown]
# ## Analysis with Re

# %%
testing_nue = 1/np.linspace(15., 300., 50).reshape(-1)

xlim = [-0.5, 1.0]
ylim = [-0.5, 1.5]
grid_size = 64
sens_dir = '../Trained_models/KF_PINTO/seq_data.csv'

x, y, tno_test_true, tno_test_pred, tno_ts_u_val, tno_ts_v_val = get_true_test_values(
    model=PINTO_model, nue=testing_nue, 
    xlim=xlim, ylim=ylim, grid_size=grid_size,sens_dir=sens_dir)

# %%
rel_err = (abs(np.concatenate(tno_test_true, axis=0) - np.concatenate(tno_test_pred, axis=0))/(1 + abs(np.concatenate(tno_test_true)))).reshape(-1, 64, 64)
re_df = pd.DataFrame({'testing_Re': 1/testing_nue, 'rel_er': np.mean(rel_err.reshape(20, -1), axis=-1)})
re_df.to_csv('Relative_error_vs_Re.csv')

# %% [markdown]
# ## Inference Time

# %%
xdisc = np.linspace(0, 1, 256)
ydisc = np.linspace(0, 1, 256)
X, Y = np.meshgrid(xdisc, ydisc)
xin = X.reshape((-1, 1))
yin  = Y.reshape((-1, 1))
x_sen = np.random.rand(len(xin), 80)
y_sen = np.random.rand(len(xin), 80)
u_sen = np.random.rand(len(xin), 80)
v_sen = np.random.rand(len(xin), 80)
p_sen = np.random.rand(len(xin), 80)

_ = PINTO_model.predict([xin, yin , x_sen, y_sen, u_sen, v_sen, p_sen], batch_size=256*256, verbose=0)
for i in range(10):
    _ = model.predict([xin, yin , x_sen, y_sen, u_sen, v_sen, p_sen], batch_size=256*256)
# Out:
# 2025-04-13 15:32:31.743925: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.50GiB (rounded to 2684354560)requested by op model/multi_head_attention/key/einsum/Einsum
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-04-13 15:32:31.744019: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2025-04-13 15:32:31.744061: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 129, Chunks in use: 129. 32.2KiB allocated for chunks. 32.2KiB in use in bin. 20.7KiB client-requested in use in bin.
# 2025-04-13 15:32:31.744089: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 15, Chunks in use: 15. 8.5KiB allocated for chunks. 8.5KiB in use in bin. 8.0KiB client-requested in use in bin.
# 2025-04-13 15:32:31.744114: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2025-04-13 15:32:31.744139: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744162: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744186: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 1, Chunks in use: 0. 14.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744210: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 76, Chunks in use: 76. 1.23MiB allocated for chunks. 1.23MiB in use in bin. 1.21MiB client-requested in use in bin.
# 2025-04-13 15:32:31.744239: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 16, Chunks in use: 11. 652.2KiB allocated for chunks. 420.8KiB in use in bin. 316.0KiB client-requested in use in bin.
# 2025-04-13 15:32:31.744262: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744283: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744348: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 512.0KiB allocated for chunks. 512.0KiB in use in bin. 512.0KiB client-requested in use in bin.
# 2025-04-13 15:32:31.744378: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744405: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 28, Chunks in use: 27. 35.00MiB allocated for chunks. 33.75MiB in use in bin. 33.75MiB client-requested in use in bin.
# 2025-04-13 15:32:31.744430: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 5, Chunks in use: 2. 14.32MiB allocated for chunks. 4.77MiB in use in bin. 2.50MiB client-requested in use in bin.
# 2025-04-13 15:32:31.744454: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 3, Chunks in use: 0. 16.25MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744475: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744502: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 7, Chunks in use: 6. 132.00MiB allocated for chunks. 116.00MiB in use in bin. 116.00MiB client-requested in use in bin.
# 2025-04-13 15:32:31.744527: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 32.00MiB allocated for chunks. 32.00MiB in use in bin. 32.00MiB client-requested in use in bin.
# 2025-04-13 15:32:31.744549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744581: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-04-13 15:32:31.744606: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 4, Chunks in use: 2. 5.91GiB allocated for chunks. 2.50GiB in use in bin. 2.50GiB client-requested in use in bin.
# 2025-04-13 15:32:31.744631: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 2.50GiB was 256.00MiB, Chunk State:
# 2025-04-13 15:32:31.744666: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 1.38GiB | Requested Size: 1.25GiB | in_use: 0 | bin_num: 20, prev:   Size: 1.25GiB | Requested Size: 1.25GiB | in_use: 1 | bin_num: -1, next:   Size: 1.25GiB | Requested Size: 1.25GiB | in_use: 1 | bin_num: -1
# 2025-04-13 15:32:31.744693: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 2.03GiB | Requested Size: 8B | in_use: 0 | bin_num: 20, prev:   Size: 1.25GiB | Requested Size: 1.25GiB | in_use: 1 | bin_num: -1
# 2025-04-13 15:32:31.744713: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 6588792832
# 2025-04-13 15:32:31.744736: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000000 of size 256 next 1
# 2025-04-13 15:32:31.744756: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000100 of size 1280 next 2
# 2025-04-13 15:32:31.744776: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000600 of size 256 next 3
# 2025-04-13 15:32:31.744795: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000700 of size 256 next 4
# 2025-04-13 15:32:31.744813: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000800 of size 256 next 6
# 2025-04-13 15:32:31.744832: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000900 of size 256 next 7
# 2025-04-13 15:32:31.744851: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000a00 of size 256 next 5
# 2025-04-13 15:32:31.744870: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000b00 of size 256 next 8
# 2025-04-13 15:32:31.744888: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000c00 of size 256 next 13
# 2025-04-13 15:32:31.744907: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000d00 of size 256 next 11
# 2025-04-13 15:32:31.744926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000e00 of size 256 next 9
# 2025-04-13 15:32:31.744945: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790000f00 of size 256 next 19
# 2025-04-13 15:32:31.744963: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001000 of size 256 next 18
# 2025-04-13 15:32:31.744983: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001100 of size 512 next 20
# 2025-04-13 15:32:31.745003: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001300 of size 256 next 12
# 2025-04-13 15:32:31.745022: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001400 of size 256 next 16
# 2025-04-13 15:32:31.745041: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001500 of size 512 next 14
# 2025-04-13 15:32:31.745060: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001700 of size 512 next 15
# 2025-04-13 15:32:31.745079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb790001900 of size 256 next 22
# 2025-04-13 15:32:31.745098: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7bb
I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 11 Chunks of size 20480 totalling 220.0KiB
# 2025-04-13 15:32:31.751248: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 32768 totalling 128.0KiB
# 2025-04-13 15:32:31.751252: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 36864 totalling 108.0KiB
# 2025-04-13 15:32:31.751256: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 43008 totalling 42.0KiB
# 2025-04-13 15:32:31.751260: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 47616 totalling 46.5KiB
# 2025-04-13 15:32:31.751264: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 49152 totalling 48.0KiB
# 2025-04-13 15:32:31.751268: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 49408 totalling 48.2KiB
# 2025-04-13 15:32:31.751272: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 262144 totalling 512.0KiB
# 2025-04-13 15:32:31.751276: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 27 Chunks of size 1310720 totalling 33.75MiB
# 2025-04-13 15:32:31.751280: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2397952 totalling 2.29MiB
# 2025-04-13 15:32:31.751284: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2605056 totalling 2.48MiB
# 2025-04-13 15:32:31.751288: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 16777216 totalling 16.00MiB
# 2025-04-13 15:32:31.751292: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 20971520 totalling 100.00MiB
# 2025-04-13 15:32:31.751298: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 33554432 totalling 32.00MiB
# 2025-04-13 15:32:31.751321: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1342177280 totalling 2.50GiB
# 2025-04-13 15:32:31.751325: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 2.68GiB
# 2025-04-13 15:32:31.751329: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 6588792832 memory_limit_: 6588792832 available bytes: 0 curr_region_allocation_bytes_: 13177585664
# 2025-04-13 15:32:31.751345: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      6588792832
# InUse:                      2882225664
# MaxInUse:                   4224403200
# NumAllocs:                        3967
# MaxAllocSize:               1342177280
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-04-13 15:32:31.751370: W external/local_tsl/tsl/framework/bfc_allocator.cc:497] *************************_____________________*********************_________________________________
# 2025-04-13 15:32:31.751381: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at einsum_op_impl.h:531 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[5242880,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[19], line 12
#       9 v_sen = np.random.rand(len(xin), 80)
#      10 p_sen = np.random.rand(len(xin), 80)
# ---> 12 _ = PINTO_model.predict([xin, yin , x_sen, y_sen, u_sen, v_sen, p_sen], batch_size=256*256, verbose=0)
#      13 for i in range(10):
#      14     _ = model.predict([xin, yin , x_sen, y_sen, u_sen, v_sen, p_sen], batch_size=256*256)
#
# File ~/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/tf_venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node model/multi_head_attention/key/einsum/Einsum defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#
#   File "/tmp/ipykernel_677069/1049721911.py", line 12, in <module>
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 2655, in predict
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 2440, in predict_function
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 2425, in step_function
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 2413, in run_step
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 2381, in predict_step
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/training.py", line 590, in __call__
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/layers/attention/multi_head_attention.py", line 595, in call
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/home/sumanth/tf_venv/lib/python3.10/site-packages/keras/src/layers/core/einsum_dense.py", line 207, in call
#
# OOM when allocating tensor with shape[5242880,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/multi_head_attention/key/einsum/Einsum}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_predict_function_18762]
